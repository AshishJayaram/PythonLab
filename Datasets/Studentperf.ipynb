# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv('./StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch test preparation course  mathscore  reading score  writing score
# 0  female        group B           bachelor's degree      standard                    none         72             72             74
# 1  female        group C                         NaN      standard               completed         69             90             88
# 2  female        group B             master's degree      standard                    none         90             95             93
# 3    male        group A          associate's degree  free/reduced                    none         47             57             44
# 4    male        group C                         NaN      standard                    none         76             78             75

# %%
df.columns
# Out:
# Index([u'gender', u'race/ethnicity', u'parental level of education', u'lunch',
#        u'test preparation course', u'mathscore', u'reading score',
#        u'writing score'],
#       dtype='object')

# %%
df.describe()
# Out:
#          mathscore  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     65.969000      69.169000      68.054000
# std      15.310338      14.600192      15.195657
# min       0.000000      17.000000      10.000000
# 25%      56.750000      59.000000      57.750000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df.drop(['lunch', 'test preparation course'], inplace=True, axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education  mathscore  reading score  writing score
# 0  female        group B           bachelor's degree         72             72             74
# 1  female        group C                         NaN         69             90             88
# 2  female        group B             master's degree         90             95             93
# 3    male        group A          associate's degree         47             57             44
# 4    male        group C                         NaN         76             78             75

# %%
df.rename(columns={
    'parental level of education': 'parent_edu',
    'race/ethnicity': 'race'
}, inplace=True)

# %%
df.head()
# Out:
#    gender     race          parent_edu  mathscore  reading score  writing score
# 0  female  group B   bachelor's degree         72             72             74
# 1  female  group C                 NaN         69             90             88
# 2  female  group B     master's degree         90             95             93
# 3    male  group A  associate's degree         47             57             44
# 4    male  group C                 NaN         76             78             75

# %%
df.parent_edu.fillna('10th pass', inplace=True)

# %%
df.head()
# Out:
#    gender     race          parent_edu  mathscore  reading score  writing score
# 0  female  group B   bachelor's degree         72             72             74
# 1  female  group C           10th pass         69             90             88
# 2  female  group B     master's degree         90             95             93
# 3    male  group A  associate's degree         47             57             44
# 4    male  group C           10th pass         76             78             75

# %%
df.rename(columns={
    'parent_edu': 'parent_eduparental level of education',
    'race': 'race/ethnicity'
}, inplace=True)

# %%
df.head()
# Out:
#    gender race/ethnicity parent_eduparental level of education  mathscore  reading score  writing score
# 0  female        group B                     bachelor's degree         72             72             74
# 1  female        group C                             10th pass         69             90             88
# 2  female        group B                       master's degree         90             95             93
# 3    male        group A                    associate's degree         47             57             44
# 4    male        group C                             10th pass         76             78             75

# %%
df.race = df.race.map({
    'group A': 'Asian',
    'group B': 'African',
    'group C': 'Afro-asian',
    'group D': 'American',
    'group E': 'Europen'
})

# %%
df.head()
# Out:
#    gender        race parent_eduparental level of education  mathscore  reading score  writing score
# 0  female     African                     bachelor's degree         72             72             74
# 1  female  Afro-asian                             10th pass         69             90             88
# 2  female     African                       master's degree         90             95             93
# 3    male       Asian                    associate's degree         47             57             44
# 4    male  Afro-asian                             10th pass         76             78             75

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-fc6234eabdcb> in <module>()
# ----> 1 plot = sb.countplot(x=df['test preparation course'], hue=df.gender)
#       2 plot.set(title = 'Passenger status (Survived/Died) against Passenger Class',
#       3        xlabel = 'PassengerClass', ylabel = 'Total')
#       4 plt.show()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
# ...
